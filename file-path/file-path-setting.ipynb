# %%
import pandas as pd

# %%
# !move "C:\Users\COM\Downloads\전라남도.csv" .
# Out:
#         1개 파일을 이동했습니다.

# %%
# %pwd
# Out:
# 'C:\\Users\\COM\\Desktop\\DS_edwith\\file-path'

# %%
pd.read_csv("Data/전라남도.csv", encoding="cp949")
# Out:
#         상호명                     도로명주소                     지번주소          전화번호  \
# 0       NaN       전라남도 진도군 진도읍 남문길 25   전라남도 진도군 진도읍 남동리 776-3           NaN
# 1       NaN                       NaN   전라남도 진도군 진도읍 동외리 536-3           NaN
# 2       NaN                       NaN   전라남도 진도군 진도읍 동외리 536-4           NaN
# 3      대영빌라       전라남도 진도군 진도읍 성내길 28   전라남도 진도군 진도읍 성내리 22-57  061-544-2132
# 4     오일빌원룸     전라남도 진도군 고군면 오일시1길 59     전라남도 진도군 고군면 고성리 247           NaN
# 5     오일빌원룸                       NaN   전라남도 진도군 고군면 고성리 248-8           NaN
# 6       NaN                       NaN     전라남도 진도군 고군면 금계리 644           NaN
# 7       NaN                       NaN   전라남도 진도군 고군면 금계리 644-1           NaN
# 8       NaN   전라남도 진도군 고군면 원포길 150-13   전라남도 진도군 고군면 원포리 277-1           NaN
# 9       NaN       전라남도 진도군 진도읍 성북길 29    전라남도 진도군 진도읍 교동리 54-3           NaN
# 10      NaN       전라남도 진도군 진도읍 남문길 23  전라남도 진도군 진도읍 남동리 776-22           NaN
# ...

# %%
# %pwd
# Out:
# 'C:\\Users\\COM\\Desktop\\DS_edwith\\file-path'

# %%
import pandas as pd

# %%
pd.read_csv("Data/전라남도.csv", encoding="949")
# Out:
#         상호명                     도로명주소                     지번주소          전화번호  \
# 0       NaN       전라남도 진도군 진도읍 남문길 25   전라남도 진도군 진도읍 남동리 776-3           NaN
# 1       NaN                       NaN   전라남도 진도군 진도읍 동외리 536-3           NaN
# 2       NaN                       NaN   전라남도 진도군 진도읍 동외리 536-4           NaN
# 3      대영빌라       전라남도 진도군 진도읍 성내길 28   전라남도 진도군 진도읍 성내리 22-57  061-544-2132
# 4     오일빌원룸     전라남도 진도군 고군면 오일시1길 59     전라남도 진도군 고군면 고성리 247           NaN
# 5     오일빌원룸                       NaN   전라남도 진도군 고군면 고성리 248-8           NaN
# 6       NaN                       NaN     전라남도 진도군 고군면 금계리 644           NaN
# 7       NaN                       NaN   전라남도 진도군 고군면 금계리 644-1           NaN
# 8       NaN   전라남도 진도군 고군면 원포길 150-13   전라남도 진도군 고군면 원포리 277-1           NaN
# 9       NaN       전라남도 진도군 진도읍 성북길 29    전라남도 진도군 진도읍 교동리 54-3           NaN
# 10      NaN       전라남도 진도군 진도읍 남문길 23  전라남도 진도군 진도읍 남동리 776-22           NaN
# ...
